# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate   
import seaborn as sns

# %%
df=pd.read_csv('AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.describe()            # Summary statistics of the dataset
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.isnull().sum()               #count of Missing values in dataset
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.info()                    # Count of non null values in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
def get_column_datatype(column):
    if df[column].dtype=="object":
        return "categorical"
    else:
        return "numerical"
categorical_columns=[]
numerical_columns=[]
for column in df.columns:
    column_datatype=get_column_datatype(column)
    if column_datatype=="categorical":
        categorical_columns.append(column)
    else:
        numerical_columns.append(column)
print("Categorical Columns:")        
print(categorical_columns)
print("\nNumerical Columns:")        
print(numerical_columns)
# Out:
# Categorical Columns:
# ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'last_review']
#
# Numerical Columns:
# ['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
#replacing missing values by mode
name_mode = df.name.mode()[0]
df["name"].fillna(name_mode, inplace = True)

# %%
last_review_mode=df.last_review.mode()[0]
df["last_review"].fillna(last_review_mode, inplace = True)

# %%
# dropping rows where host name is not provided
df=df.dropna(subset=['host_name'])

# %%
#imputing mean in numerical columns with missing values
df['reviews_per_month'].fillna(df['reviews_per_month'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
#box plot for numerical columns
for column in numerical_columns:
    sns.boxplot(data=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
#Removing outliers by IQR method

# %%
columns_with_outliers=['host_id','latitude','longitude','price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count']
for column in columns_with_outliers:
    Q1= df[column].quantile(0.25)
    Q3= df[column].quantile(0.75)
    IQR= Q3-Q1
    lower_bound= Q1-1.5*IQR
    upper_bound= Q3+1.5*IQR
    
    df=df[(df[column]>=lower_bound) & (df[column]<=upper_bound)]

# %%
df
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 10         5295                   Beautiful 1br on Upper West Side       7702
# 19         7750                  Huge 2 BR Upper East  Cental Park      17985
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# ...         ...                                                ...        ...
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
df.to_csv('airbnb_preprossed_data_capstone_project3.csv', index=False)        #exporting the preprossed df as csv file
